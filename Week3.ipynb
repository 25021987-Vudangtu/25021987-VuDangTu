# %% [markdown]
# <a href="https://colab.research.google.com/github/25021987-Vudangtu/25021987-VuDangTu/blob/master/Week3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Bai 1

# %%
n = int(input("Nhập số nguyên n: "))
if n < 0:
    print(-int(str(-n)[::-1]))
else:
    print(int(str(n)[::-1]))

# %% [markdown]
# #Bai 2

# %%
a = int(input("Nhập a: "))
b = int(input("Nhập b: "))
a = a ^ b
b = a ^ b
a = a ^ b
print(f"Sau hoán đổi: a = {a}, b = {b}")

# %% [markdown]
# #Bai 3

# %%
n = int(input("Nhập số nguyên n: "))
if n > 0 and (n & (n - 1)) == 0:
    print("True")
else:
    print("False")

# %% [markdown]
# #Bai 4

# %%
import math
m = int(input("Nhập m: "))
n = int(input("Nhập n (khác 0): "))
print("Làm tròn xuống:", m // n)

# %% [markdown]
# #Bai 5

# %%
import math
m = int(input("Nhập m: "))
n = int(input("Nhập n (khác 0): "))
print("Làm tròn lên:", math.ceil(m / n))

# %% [markdown]
# #Bai 6

# %%
n = int(input("Nhập số: "))
print("Even" if n % 2 == 0 else "Odd")

# %% [markdown]
# #Bai 7

# %%
a = int(input("Nhập a: "))
b = int(input("Nhập b: "))
print("Yes" if a < 0 and b < 0 else "No")

# %% [markdown]
# #Bai 8

# %%
a = input("Nhập chuỗi a: ")
b = input("Nhập chuỗi b: ")
print("True" if len(a) > len(b) else "False")

# %% [markdown]
# #Bai 9

# %%
a = int(input("Nhập a: "))
b = int(input("Nhập b: "))
c = int(input("Nhập c: "))
if a + b > c and a + c > b and b + c > a:
    print("Yes")
else:
    print("No")

# %% [markdown]
# #Bai 9

# %%
xa = int(input("Nhập a: "))
b = int(input("Nhập b: "))
c = int(input("Nhập c: "))
d = int(input("Nhập d: "))
print("Max =", max(a, b, c, d))

# %% [markdown]
# #Bai 10

# %%
a = int(input("Nhập a: "))
b = int(input("Nhập b: "))
c = int(input("Nhập c: "))
if a + b <= c or a + c <= b or b + c <= a:
    print("Không phải tam giác")
elif a == b == c:
    print("Tam giác đều")
elif a == b or b == c or a == c:
    print("Tam giác cân")
else:
    print("Tam giác thường")

# %% [markdown]
# #Bai 11

# %%
y = int(input("Nhập năm: "))
if (y % 4 == 0 and y % 100 != 0) or (y % 400 == 0):
    print("Yes")
else:
    print("No")

# %% [markdown]
# #Bai 12

# %%
kwh = int(input("Nhập số kWh tiêu thụ: "))
if kwh <= 50:
    bill = kwh * 1500
elif kwh <= 100:
    bill = 50 * 1500 + (kwh - 50) * 2000
else:
    bill = 50 * 1500 + 50 * 2000 + (kwh - 100) * 3000
print("Tiền điện:", bill)

# %% [markdown]
# #Bai 13

# %%
a = float(input("Nhập a: "))
b = float(input("Nhập b: "))
if a == 0:
    if b == 0:
        print("Vô số nghiệm")
    else:
        print("Vô nghiệm")
else:
    print("Nghiệm:", round(-b / a, 2))

# %% [markdown]
# #Bai 14

# %%
g = float(input("Nhập điểm trung bình: "))
if g >= 8.5:
    print("Giỏi")
elif g >= 7:
    print("Khá")
elif g >= 5:
    print("Trung bình")
else:
    print("Yếu")

# %% [markdown]
# #Bai 15

# %%
x = float(input("Nhập một số thực: "))
down = int(x) if x >= 0 else int(x) - (1 if x != int(x) else 0)
up = int(x) + (1 if x > int(x) else 0) if x >= 0 else int(x)
fraction = x - int(x)
if x >= 0:
    nearest = int(x) + (1 if fraction >= 0.5 else 0)
else:
    nearest = int(x) - (1 if abs(fraction) >= 0.5 else 0)
print(up, down, nearest)
