# %% [markdown]
# <a href="https://colab.research.google.com/github/25021987-Vudangtu/25021987-VuDangTu/blob/master/Week5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#BAI1
def Maxoftwo(a,b):
  return max(a,b)
a,b=map(int,input().split())
print(Maxoftwo(a,b))
# Out:
# 5 77
# 77

# %%
#BAI2
def swap(a,b):
  a,b=b,a
  return a,b
x,y=map(int,input().split())
x,y=swap(x,y)

print(x,y)
# Out:
# 5 7
# 7 5

# %%
#BAI3
def prime(x):
  if x<2:return False
  elif x>=2:
    for i in range(2,int(x**(1/2))+1):
      if x%i==0: return False
  return True
a=int(input())
if def(a):
  print("True")
else:
  print("False")
# Out:
#   File "/tmp/ipython-input-1368062961.py", line 9
#     if def(a):
#        ^
# SyntaxError: invalid syntax
