# %% [markdown]
# <a href="https://colab.research.google.com/github/25021987-Vudangtu/25021987-VuDangTu/blob/master/Week8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#BAI1
class Cylinder:
  def __init__(self,r,l):
    self.r=r
    self.l=l
  def dientich(self):
    S=(2*3.14*(r**2))+(2*3.14*r)*l
    return S
  def thetich(self):
    V=3.14*r**2*l
    return V
r,l=map(int,input().split())
C1=Cylinder(r,l)
print(f"{C1.dientich():.2f}")
print(f"{C1.thetich():.2f}")
# Out:
# 8 1
# 452.16
# 200.96

# %%
class Oxy:
  def __init__(self,x,y):
    self.x=x
    self.y=y
  def ktvitri(self):
    if x==y==0:
      print("day la goc toa do")
    else:
      print("khong phai goc toa do")
    if x==0:
      print("diem thuoc truc tung")
    else:print("diemr khong thuoc truc tung")
    if y==0:
      print("diem thuoc truc hoanh")
    else:
      print("diem khong thuoc trucn hoanh")

  def kcach(self):
    kc=(x**2+y**2)**0.5
    print(f"khoang cach tu diem den goc O la {kc:.2f}")
x,y=map(int,input().split())
M=Oxy(x,y)
M.ktvitri()
M.kcach()
# Out:
# 0 7
# khong phai goc toa do
# diem thuoc truc tung
# diem khong thuoc trucn hoanh
# khoang cach tu diem den goc O la 7.00
